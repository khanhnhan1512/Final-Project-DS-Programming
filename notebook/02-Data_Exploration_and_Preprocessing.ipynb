# %% [markdown]
# <div style="text-align: center; color: white; background-color: #559cff; font-weight: bold; padding: 20px" >
#  <p style="font-size: 40px"> Final Project - Programming for Data Science 📚</p>
#  <p style="font-size: 30px"><u>Phase 2:</u> Data Exploration and Preprocessing 🕵️</p>
#
# </div>
#
#
# ---

# %% [markdown]
# ## Member Information
# | Name              | ID       |
# |-------------------|----------|
# | Nguyen Khanh Nhan | 21127657         |
# | Tran Dai Nien     | 21127664 |

# %% [markdown]
# ## Table of Contents
# - [0. Import libraries](#0-import-libraries)
# - [1. Load data](#1-load-data)
# - [2. Basic information about the dataset](#2-basic-information-about-the-dataset)
#     - [2.1 Context of the dataset](#21-context)
#     - [2.2 Meaning of each column](#22-meaning-of-each-columns)
# - [3. Specific information about the dataset](#3-specific-information-about-the-dataset)
#     - [3.1 Rows and columns](#31-rows-and-columns)
#     - [3.2 Meaning of each row](#32-what-is-the-meaning-of-each-row)
#     - [3.3 Duplicated rows](#33-are-there-duplicated-rows)
#     - [3.4 Column data types](#34-column-data-type)
#     - [3.5 Missing values on each row](#35-missing-values-on-each-row)
# - [4. Incorrect values and outliers](#4-check-incorrect-values-and-outliers)
# - [5. Numerical column](#5-numerical-column)
#     - [5.1 Missing values](#51-missing-values)
#     - [5.2 Distribution and descriptive statistics](#52-distribution-and-descriptive-statistics-of-numerical-attributes)
# - [6. Categorical column](#6-categorical-column)
#     - [6.1 Missing values](#61-missing-values)
#     - [6.2 Different values in categorical columns](#62-different-values-in-each-categorical-column)
# - [7. Correlation between attributes](#7-correlation-between-attributes)
#
# ---

# %% [markdown]
# ## 0. Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Load data

# %%
df = pd.read_csv('./data/spotify-2023.csv', encoding='Latin-1', thousands=',')

# get 5 random samples
df.sample(5)
# Out:
#                          track_name              artist(s)_name  artist_count  \
# 344   Apna Bana Le (From "Bhediya")  Arijit Singh, Sachin-Jigar             2
# 943              Privileged Rappers            Drake, 21 Savage             2
# 286                        En Paris       El Chachito, Junior H             2
# 626  Fair Trade (with Travis Scott)         Drake, Travis Scott             2
# 862  Master of Puppets (Remastered)                   Metallica             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 344           2022              11             5                    86
# 943           2022              11             4                  1007
# 286           2022              12            24                   406
# 626           2021               9             3                  5403
# 862           1986               3             3                  6080
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm  key   mode  \
# 344                  0  139836056                  11  ...   94    A  Major
# 943                  0  112436403                   6  ...  144    F  Major
# 286                  5  198275403                   3  ...  139   D#  Minor
# 626                  6  593917618                 118  ...  168   C#  Major
# 862                  0  704171068                 112  ...  105    E  Minor
#
#      danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 344              59         44       56             80                   0
# 943              93         62       61              0                   0
# 286              70         77       48             37                   0
# 626              67         29       47              5                   0
# 862              54         59       83              0                  44
#
#      liveness_%  speechiness_%
# 344           6              3
# 943          12             20
# 286          12              5
# 626          22             26
# 862          20              4
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 2. Basic information about the dataset

# %% [markdown]
# ### 2.1 Context

# %% [markdown]
# - Most famous songs of 2023 as listed on `Spotify`

# %% [markdown]
# ### 2.2 Meaning of each columns

# %% [markdown]
# | Column                 | Meaning                                                      |
# |------------------------|--------------------------------------------------------------|
# | `track_name`           | Name of the song.                                            |
# | `artist(s)_name`       | Name of the artist(s) of the song.                           |
# | `artist_count`         | Number of artists contributing to the song.                  |
# | `released_year`        | Year when the song was released.                             |
# | `released_month`       | Month when the song was released.                            |
# | `released_day`         | Day of the month when the song was released.                 |
# | `in_spotify_playlists` | Number of Spotify playlists the song is included in.        |
# | `in_spotify_charts`    | Presence and rank of the song on Spotify charts.             |
# | `streams`              | Total number of streams on Spotify.                         |
# | `in_apple_playlists`   | Number of Apple Music playlists of the song is included in. |
# | `in_apple_charts`      | Presence and rank of the song on Apple Music charts.         |
# | `in_deezer_playlists`  | Number of Deezer playlists the song is included in.          |
# | `in_deezer_charts`     | Presence and rank of the song on Deezer charts.              |
# | `in_shazam_charts`     | Presence and rank of the song on Shazam charts.              |
# | `bpm`                  | Beats per minute, a measure of song tempo.                   |
# | `key`                  | Key of the song.                                             |
# | `mode`                 | Mode of the song (major or minor).                           |
# | `danceability_%`       | Percentage indicating how suitable the song is for dancing.  |
# | `valence_%`            | Positivity of the song's musical content.                    |
# | `energy_%`             | Perceived energy level of the song.                          |
# | `acousticness_%`       | Amount of acoustic sound in the song.                        |
# | `instrumentalness_%`   | Amount of instrumental content in the song.                  |
# | `liveness_%`           | Presence of live performance elements.                       |
# | `speechiness_%`        | Amount of spoken words in the song.                          |

# %% [markdown]
# ## 3. Specific information about the dataset

# %% [markdown]
# ### 3.1 Rows and columns

# %%
print(f"The number of rows is {df.shape[0]}")
print(f"The number of columns is {df.shape[1]}")
# Out:
# The number of rows is 953
# The number of columns is 24

# %% [markdown]
# ✅The dataset has `953` rows and `24` columns.

# %%
col_name = df.columns
print(f"Tên các cột của dữ liệu: {col_name}")
# Out:
# Tên các cột của dữ liệu: Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %% [markdown]
# ### 3.2 What is the meaning of each row?

# %% [markdown]
# ✅ A row represents the information of a song (`name`, `artist_name`, `released year`,...) and some of its properties in `Spotify` in 2023.

# %% [markdown]
# ### 3.3 Are there duplicated rows?

# %%
print(f"The dataset has {df.duplicated().sum()} duplicated rows")
# Out:
# The dataset has 0 duplicated rows

# %% [markdown]
# ✅ There is no duplicated rows in our dataset.

# %% [markdown]
# ### 3.4 Column data type

# %% [markdown]
# - Now, we will check the data type of each column.

# %%
df.dtypes
# Out:
# track_name               object
# artist(s)_name           object
# artist_count              int64
# released_year             int64
# released_month            int64
# released_day              int64
# in_spotify_playlists      int64
# in_spotify_charts         int64
# streams                  object
# in_apple_playlists        int64
# in_apple_charts           int64
# in_deezer_playlists       int64
# in_deezer_charts          int64
# in_shazam_charts        float64
# bpm                       int64
# key                      object
# mode                     object
# danceability_%            int64
# valence_%                 int64
# energy_%                  int64
# acousticness_%            int64
# instrumentalness_%        int64
# liveness_%                int64
# speechiness_%             int64
# dtype: object

# %% [markdown]
# ✅ There are some inapropriate column's data types:
#
# - `streams` must be `int64` type.

# %% [markdown]
# 🔧 Convert to `int64` type.

# %%
ob_to_int_cols = ['streams']

for col in ob_to_int_cols:
  df[col] = pd.to_numeric(df[col], errors='coerce')

# %% [markdown]
# ✅ Check the data type of each column again to make sure that we have converted them successfully.

# %%
df.dtypes
# Out:
# track_name               object
# artist(s)_name           object
# artist_count              int64
# released_year             int64
# released_month            int64
# released_day              int64
# in_spotify_playlists      int64
# in_spotify_charts         int64
# streams                 float64
# in_apple_playlists        int64
# in_apple_charts           int64
# in_deezer_playlists       int64
# in_deezer_charts          int64
# in_shazam_charts        float64
# bpm                       int64
# key                      object
# mode                     object
# danceability_%            int64
# valence_%                 int64
# energy_%                  int64
# acousticness_%            int64
# instrumentalness_%        int64
# liveness_%                int64
# speechiness_%             int64
# dtype: object

# %% [markdown]
# ❌ There is a strange thing that after converting, `streams`, is now `float64` type not `int64` type. <br>
# ✅ The reason is that there are some `NaN` values in these columns. Based on the rule of `pandas`, if there is at least one `NaN` value in a `int64` column, the data type of that column will be `float64` type. This is called `upcasting`. So, for now we will leave it like that.

# %% [markdown]
# ### 3.5 Missing values on each row

# %% [markdown]
# 🕵️ We will check the number of missing value in each row.  <br>
# - In our dataset, each row has `24` columns. So, if a row has more than `12` missing values, we will **drop** it.

# %%
# Count the number of missing values in each row
missing_values_per_row = df.isnull().sum(axis=1)

# Count the number of rows for each count of missing values
count_of_missing_values = missing_values_per_row.value_counts().sort_index()

for missing_count, row_count in count_of_missing_values.items():
    percentage = round(row_count * 100.0 / df.shape[0], 2)
    print(f"The number of rows missing {missing_count} values: {row_count} rows ({percentage}%).")

total_percentage = round(sum(count_of_missing_values[1:]) * 100.0 / df.shape[0], 2)
print(f'\nThe number of rows with missing data: {sum(count_of_missing_values[1:])} ({total_percentage}%)')
# Out:
# The number of rows missing 0 values: 816 rows (85.62%).
# The number of rows missing 1 values: 128 rows (13.43%).
# The number of rows missing 2 values: 9 rows (0.94%).
#
# The number of rows with missing data: 137 (14.38%)

# %% [markdown]
# ✅ **Comment:** <br>
# - There is no row that has more than `12` missing values. So, we don't need to drop any row. <br>
# - In total, there are `137` rows that contain missing values but the number of missing values in each row is very small (`1`, `2` ).

# %% [markdown]
# ## 4. Check Incorrect values and outliers

# %% [markdown]
# 🕵️ There are quite a few songs and artist names that contain `special character (¿)`, resulting in incorrect entries. We will examine how many songs and artists have special characters. If there are only a few, we will make the necessary corrections. However, if there are too many, we will consider removing them (as it may not be feasible to manually fix each song and artist name).

# %%
wrong_name = list(df[(df['artist(s)_name'].str.contains('¿')) | (df['track_name'].str.contains('¿'))][['artist(s)_name', 'track_name']].index)

# %% [markdown]
# 🔧 Remove rows that have `special character (¿)` in `track_name` and `artist(s)_name` columns.

# %%
df = df.drop(wrong_name, axis=0)

# %% [markdown]
# ✅ Save the cleaned dataset to a new file.

# %%
df.to_csv('./data/processed_spotify-2023.csv', index=False)

# %% [markdown]
# 🕵️Finally, as we observed the distribution of numerical columns above, there is **no abnormal value** so we will only check the outliers for some numerical columns in our dataset. We will use `boxplot` to check the outliers.

# %%
outlier_cols = ['in_spotify_playlists',
       'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
       'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
        'danceability_%', 'valence_%', 'energy_%',
       'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
for col, i in zip(outlier_cols, range(len(outlier_cols))):
    sns.boxplot(df[col], ax=axes[i//4][i%4])
    axes[i//4][i%4].set_title(col)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# 🕵️ Or we can also use `violin plot` with `box` inside. We will observe the `violin plot` of these columns by `mode`.

# %%
fig, axes = plt.subplots(8, 2, figsize=(12, 32))
for col, ax, i in zip(outlier_cols, axes.flatten(), range(len(outlier_cols))):
    sns.violinplot(hue='mode', y=col, data=df, palette='pastel', ax=ax, inner='box')
    ax.set_title(f"Violin plot of {col} by mode")
    ax.set_xlabel('Mode')
    ax.set_ylabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ✅**Comment:**
# - Columns related to the features of the songs, such as `bpm`, `danceability_%`, `valence_%`, `energy_%`, and `acousticness_%`, have either no or very few outliers. This indicates that the songs are quite similar in terms of these aspects. However, `instrumentalness_%`, `liveness_%`, and `speechiness_%` have some relatively large outliers. This is also understandable because these factors can vary depending on the genre of the song.
# - Columns related to rankings, number of listeners, and streams also have **many outliers**. This is expected because these columns have a **wide range of values** due to the popularity of songs. Famous songs tend to have a high number of listeners, streams, and rankings, while less popular songs have fewer listeners, streams, and lower rankings.

# %% [markdown]
# ## 5. Numerical column

# %% [markdown]
# 🕵️ We will explore deeper all the numerical columns in our dataset. First, we will see which they are.

# %%
numerical_cols_df = df[df.columns[(df.dtypes == 'int64') | (df.dtypes == 'float64')]]
numerical_cols = list(numerical_cols_df.columns)
list(numerical_cols)
# Out:
# ['artist_count',
#  'released_year',
#  'released_month',
#  'released_day',
#  'in_spotify_playlists',
#  'in_spotify_charts',
#  'streams',
#  'in_apple_playlists',
#  'in_apple_charts',
#  'in_deezer_playlists',
#  'in_deezer_charts',
#  'in_shazam_charts',
#  'bpm',
#  'danceability_%',
#  'valence_%',
#  'energy_%',
#  'acousticness_%',
#  'instrumentalness_%',
#  'liveness_%',
#  'speechiness_%']

# %% [markdown]
# ✅ There are total `20` numerical columns in our dataset.

# %% [markdown]
# ####  5.1 Missing values

# %% [markdown]
# 🕵️ Number of missing values of each columns

# %%
numerical_cols_df.isna().sum()
# Out:
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  1
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        49
# bpm                      0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# 🕵️ The percentage of missing values for each columns

# %%
numerical_cols_df.isnull().mean() * 100
# Out:
# artist_count            0.000000
# released_year           0.000000
# released_month          0.000000
# released_day            0.000000
# in_spotify_playlists    0.000000
# in_spotify_charts       0.000000
# streams                 0.117925
# in_apple_playlists      0.000000
# in_apple_charts         0.000000
# in_deezer_playlists     0.000000
# in_deezer_charts        0.000000
# in_shazam_charts        5.778302
# bpm                     0.000000
# danceability_%          0.000000
# valence_%               0.000000
# energy_%                0.000000
# acousticness_%          0.000000
# instrumentalness_%      0.000000
# liveness_%              0.000000
# speechiness_%           0.000000
# dtype: float64

# %%
missing_values_per_column = numerical_cols_df.isnull().sum()
missing_values_per_column_percent = missing_values_per_column / numerical_cols_df.shape[0]
fig, ax = plt.subplots(2, 1, figsize=(10, 10))
missing_values_per_column.plot.barh(ax=ax[0])
ax[0].set_xlabel('Number of missing values')
ax[0].set_title('Number of missing values per column')
missing_values_per_column_percent.plot.barh(ax=ax[1])
ax[1].set_xlabel('Percentage of missing values (%)')
ax[1].set_title('Percentage of missing values per column')
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅**Comment:**
# - There are `2` numerical columns that have missing values: `streams`,  `in_shazam_charts`.
# - All of them have very small percentage of missing values (`<10%`), so we don't need to drop any of them.

# %% [markdown]
# 🔧 Now, we will fill the missing values in these columns:
# - The `streams` column has only one `NaN` value, so we will fill that value with the `median value` of the column. Because this column has `std` value is very large, so we will use `median` instead of `mean` to fill the missing value.
# - For the `in_deezer_playlists` column, there is problem that there is commas in the value. So, we will remove the commas.
# - `in_shazam_charts` has a significant number of missing values, so it would be best to use the `KNNImputer` to fill in the missing values. We will use `KNNImputer`to fill missing values in `in_shazam_charts` column based on the values of `in_spotify_charts`, `in_apple_charts`, `in_deezer_charts` columns. Because these columns have the same meaning.

# %%
from sklearn.impute import KNNImputer

old_df = df[['streams', 'in_shazam_charts']].copy()

# Fill missing value for streams column
df['streams'].fillna(df['streams'].median(), inplace=True)
# Remove commas
df['in_deezer_playlists'] = df['in_deezer_playlists'].replace(',', '', regex=True)
# Fill missing value for in_shazam_charts 
k_neighbours = 3
knn_imputer = KNNImputer(n_neighbors=k_neighbours)
df[['in_shazam_charts', 'in_spotify_charts', 'in_deezer_charts', 'in_apple_charts']] = knn_imputer.fit_transform(df[['in_shazam_charts', 'in_spotify_charts', 'in_deezer_charts', 'in_apple_charts']])

# %% [markdown]
# 🕵️ Check the number of missing values in each numerical column again to make sure that we have filled them successfully.

# %%
df[numerical_cols].isna().sum()
# Out:
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %% [markdown]
# ✅ Now, there is no missing value in these `2` numerical columns.

# %% [markdown]
# 🕵️To check if imputation has a negative impact on the columns, we will examine the distribution of the columns after imputation and compare it to the distribution before imputation using a `KDE plot`.
# - A `KDE plot` is commonly used to gain a better understanding of the distribution of a random variable, examine symmetry, concentration, and tails of the data, and compare distributions between different groups.

# %%
cols = ['streams', 'in_shazam_charts']
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
for col, i in zip(cols, [0, 1]):
    sns.kdeplot(old_df[col], ax=axes[i], label='original')
    sns.kdeplot(df[col], ax=axes[i], label='imputed')
    axes[i].legend()
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅We can see that the `distribution` of the columns `after imputation` is **not significantly different** from the distribution `before imputation`. Therefore, we can conclude that imputation **does not have a negative impact** on the columns.

# %% [markdown]
# ❌ One more thing is that these 2 columns must contain `int64` type values, but after filling the missing values, they now contain `float64` type values. So, we will apply `round()` function to convert them to `int64` type.

# %%
df[['streams', 'in_shazam_charts']] = df[['streams', 'in_shazam_charts']].apply(round)

# %% [markdown]
# ### 5.2 Distribution and descriptive statistics of numerical attributes

# %% [markdown]
# 🕵️ Some descriptive statistics of numerical attributes

# %%
# !pip install summarytools
# Out:
# Collecting summarytools
#   Downloading summarytools-0.2.3.tar.gz (11 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas>=1.4.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from summarytools) (1.5.3)
# Requirement already satisfied: ipython>=7.20.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from summarytools) (8.17.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from summarytools) (1.24.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from summarytools) (3.7.1)
# Requirement already satisfied: decorator in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (5.13.0)
# Requirement already satisfied: exceptiongroup in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (1.1.3)
# Requirement already satisfied: colorama in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from ipython>=7.20.0->summarytools) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from matplotlib>=3.3.0->summarytools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from matplotlib>=3.3.0->summarytools) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from matplotlib>=3.3.0->summarytools) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from matplotlib>=3.3.0->summarytools) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from matplotlib>=3.3.0->summarytools) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from matplotlib>=3.3.0->summarytools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from pandas>=1.4.0->summarytools) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from jedi>=0.16->ipython>=7.20.0->summarytools) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.20.0->summarytools) (0.2.9)
# Requirement already satisfied: six>=1.5 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->summarytools) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (0.2.2)
# Building wheels for collected packages: summarytools
#   Building wheel for summarytools (pyproject.toml): started
#   Building wheel for summarytools (pyproject.toml): finished with status 'done'
#   Created wheel for summarytools: filename=summarytools-0.2.3-py3-none-any.whl size=8592 sha256=eb3f0b214a77fcd607acd4d0040eb0f03ca7c07892bca2f3b4fd1f5b5a4b0693
#   Stored in directory: c:\users\nien\appdata\local\pip\cache\wheels\d5\8a\5d\008e2127a7f9dd64d066f16e5ea268fa52823dc929c982d6f1
# Successfully built summarytools
# Installing collected packages: summarytools
# Successfully installed summarytools-0.2.3

# %%
from summarytools import  dfSummary
dfSummary(df[numerical_cols])
# Out:
# <style type="text/css">
# #T_a6512 thead>tr>th {
#   text-align: left;
# }
# #T_a6512_row0_col0, #T_a6512_row1_col0, #T_a6512_row2_col0, #T_a6512_row3_col0, #T_a6512_row4_col0, #T_a6512_row5_col0, #T_a6512_row6_col0, #T_a6512_row7_col0, #T_a6512_row8_col0, #T_a6512_row9_col0, #T_a6512_row10_col0, #T_a6512_row11_col0, #T_a6512_row12_col0, #T_a6512_row13_col0, #T_a6512_row14_col0, #T_a6512_row15_col0, #T_a6512_row16_col0, #T_a6512_row17_col0, #T_a6512_row18_col0, #T_a6512_row19_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_a6512_row0_col1, #T_a6512_row1_col1, #T_a6512_row2_col1, #T_a6512_row3_col1, #T_a6512_row4_col1, #T_a6512_row5_col1, #T_a6512_row6_col1, #T_a6512_row7_col1, #T_a6512_row8_col1, #T_a6512_row9_col1, #T_a6512_row10_col1, #T_a6512_row11_col1, #T_a6512_row12_col1, #T_a6512_row13_col1, #T_a6512_row14_col1, #T_a6512_row15_col1, #T_a6512_row16_col1, #T_a6512_row17_col1, #T_a6512_row18_col1, #T_a6512_row19_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_a6512_row0_col2, #T_a6512_row1_col2, #T_a6512_row2_col2, #T_a6512_row3_col2, #T_a6512_row4_col2, #T_a6512_row5_col2, #T_a6512_row6_col2, #T_a6512_row7_col2, #T_a6512_row8_col2, #T_a6512_row9_col2, #T_a6512_row10_col2, #T_a6512_row11_col2, #T_a6512_row12_col2, #T_a6512_row13_col2, #T_a6512_row14_col2, #T_a6512_row15_col2, #T_a6512_row16_col2, #T_a6512_row17_col2, #T_a6512_row18_col2, #T_a6512_row19_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_a6512_row0_col3, #T_a6512_row1_col3, #T_a6512_row2_col3, #T_a6512_row3_col3, #T_a6512_row4_col3, #T_a6512_row5_col3, #T_a6512_row6_col3, #T_a6512_row7_col3, #T_a6512_row8_col3, #T_a6512_row9_col3, #T_a6512_row10_col3, #T_a6512_row11_col3, #T_a6512_row12_col3, #T_a6512_row13_col3, #T_a6512_row14_col3, #T_a6512_row15_col3, #T_a6512_row16_col3, #T_a6512_row17_col3, #T_a6512_row18_col3, #T_a6512_row19_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_a6512_row0_col4, #T_a6512_row1_col4, #T_a6512_row2_col4, #T_a6512_row3_col4, #T_a6512_row4_col4, #T_a6512_row5_col4, #T_a6512_row6_col4, #T_a6512_row7_col4, #T_a6512_row8_col4, #T_a6512_row9_col4, #T_a6512_row10_col4, #T_a6512_row11_col4, #T_a6512_row12_col4, #T_a6512_row13_col4, #T_a6512_row14_col4, #T_a6512_row15_col4, #T_a6512_row16_col4, #T_a6512_row17_col4, #T_a6512_row18_col4, #T_a6512_row19_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_a6512_row0_col5, #T_a6512_row1_col5, #T_a6512_row2_col5, #T_a6512_row3_col5, #T_a6512_row4_col5, #T_a6512_row5_col5, #T_a6512_row6_col5, #T_a6512_row7_col5, #T_a6512_row8_col5, #T_a6512_row9_col5, #T_a6512_row10_col5, #T_a6512_row11_col5, #T_a6512_row12_col5, #T_a6512_row13_col5, #T_a6512_row14_col5, #T_a6512_row15_col5, #T_a6512_row16_col5, #T_a6512_row17_col5, #T_a6512_row18_col5, #T_a6512_row19_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_a6512">
#   <caption><strong>Data Frame Summary</strong><br><br>Dimensions: 848 x 20<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_a6512_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_a6512_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_a6512_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_a6512_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_a6512_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_a6512_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a6512_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a6512_row0_col1" class="data row0 col1" ><strong>artist_count</strong><br>[int64]</td>
#       <td id="T_a6512_row0_col2" class="data row0 col2" >Mean (sd) : 1.5 (0.8)<br>min < med < max:<br>1.0 < 1.0 < 8.0<br>IQR (CV) : 1.0 (1.8)</td>
#       <td id="T_a6512_row0_col3" class="data row0 col3" >8 distinct values</td>
#       <td id="T_a6512_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_a6512_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a6512_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a6512_row1_col1" class="data row1 col1" ><strong>released_year</strong><br>[int64]</td>
#       <td id="T_a6512_row1_col2" class="data row1 col2" >Mean (sd) : 2018.0 (11.2)<br>min < med < max:<br>1942.0 < 2022.0 < 2023.0<br>IQR (CV) : 2.0 (180.8)</td>
#       <td id="T_a6512_row1_col3" class="data row1 col3" >48 distinct values</td>
#       <td id="T_a6512_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_a6512_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a6512_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a6512_row2_col1" class="data row2 col1" ><strong>released_month</strong><br>[int64]</td>
#       <td id="T_a6512_row2_col2" class="data row2 col2" >Mean (sd) : 6.1 (3.6)<br>min < med < max:<br>1.0 < 6.0 < 12.0<br>IQR (CV) : 6.0 (1.7)</td>
#       <td id="T_a6512_row2_col3" class="data row2 col3" >12 distinct values</td>
#       <td id="T_a6512_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_a6512_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a6512_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a6512_row3_col1" class="data row3 col1" ><strong>released_day</strong><br>[int64]</td>
#       <td id="T_a6512_row3_col2" class="data row3 col2" >Mean (sd) : 13.8 (9.2)<br>min < med < max:<br>1.0 < 13.0 < 31.0<br>IQR (CV) : 15.2 (1.5)</td>
#       <td id="T_a6512_row3_col3" class="data row3 col3" >31 distinct values</td>
#       <td id="T_a6512_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_a6512_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a6512_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a6512_row4_col1" class="data row4 col1" ><strong>in_spotify_playlists</strong><br>[int64]</td>
#       <td id="T_a6512_row4_col2" class="data row4 col2" >Mean (sd) : 5511.9 (8249.9)<br>min < med < max:<br>31.0 < 2310.5 < 52898.0<br>IQR (CV) : 5181.8 (0.7)</td>
#       <td id="T_a6512_row4_col3" class="data row4 col3" >788 distinct values</td>
#       <td id="T_a6512_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_a6512_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a6512_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_a6512_row5_col1" class="data row5 col1" ><strong>in_spotify_charts</strong><br>[float64]</td>
#       <td id="T_a6512_row5_col2" class="data row5 col2" >Mean (sd) : 12.4 (20.2)<br>min < med < max:<br>0.0 < 3.0 < 147.0<br>IQR (CV) : 17.0 (0.6)</td>
#       <td id="T_a6512_row5_col3" class="data row5 col3" >82 distinct values</td>
#       <td id="T_a6512_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_a6512_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a6512_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_a6512_row6_col1" class="data row6 col1" ><strong>streams</strong><br>[float64]</td>
#       <td id="T_a6512_row6_col2" class="data row6 col2" >Mean (sd) : 535155992.1 (583454350.0)<br>min < med < max:<br>2762.0 < 301051721.0 < 3703895074.0<br>IQR (CV) : 556824610.2 (0.9)</td>
#       <td id="T_a6512_row6_col3" class="data row6 col3" >843 distinct values</td>
#       <td id="T_a6512_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_a6512_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>

# %% [markdown]
# 🕵️ Distribution of numerical attributes

# %%
df[numerical_cols].hist(figsize=(15, 10), bins=5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅**Comment:**
# - `bpm`, `danceability_%`, `valence_%` and `energy_%` have distributions that are close to normal distributions.
# - Except for `released_year`, the remaining attributes have `right-skewed distributions`. It is understandable that `released_year` has a `left-skewed distribution` because the majority of the songs in the dataset were released in the `21st` century.
# - The latest released song is from the year `2023`, while the oldest song dates back to `1942`.
# - `released_month` and `released_day` have all values from `1` to `12` and `1` to `31`, respectively. This is reasonable because there are only `12` months and `31` days in a year.
# - The highest number of `streams` is `3,703,895,074`, while the lowest number of streams is `2,762`.
# - The average number of `streams` is `535,155,992.1` with a standard deviation of `583,454,350.0`, indicating large variations in online streaming counts.
# - The highest and lowest `BPM` values are `206` and `65`, with an average value of `122.6`.
# - The highest and lowest `danceability` percentages are `96%` and `23%`, with an average value of `66.4%`.
# - The highest and lowest `valence` percentages are `97%` and `4%`, with an average value of `50.4%`.
# - The highest and lowest `energy` percentages are `97%` and `9%`, with an average value of `63.8%`.
# - The highest and lowest `acousticness` percentages are `97%` and `0%`, with an average value of `26.9%`.
# - The highest and lowest `instrumentalness` percentages are `91%` and `0%`, respectively, with an average value of `1.8%`.
# - The highest and lowest `presence of live performance elements` are `92%` and `3%`, respectively, with an average value of `18%`.
# - The highest and lowest `speechiness` percentages are `59%` and `2%`, respectively, with an average value of `10%`.

# %% [markdown]
# ## 6. Categorical column

# %% [markdown]
# 🕵️ Let's look all the categorical columns in our dataset.

# %%
categorical_cols_df = df[df.columns[df.dtypes == 'object']]
categorical_cols = list(categorical_cols_df.columns)
categorical_cols
# Out:
# ['track_name', 'artist(s)_name', 'key', 'mode']

# %% [markdown]
# ### 6.1 Missing values
# 🕵️ Check the number of missing values in each categorical column.

# %%
df[categorical_cols].isna().sum()
# Out:
# track_name         0
# artist(s)_name     0
# key               89
# mode               0
# dtype: int64

# %% [markdown]
# ✅ There is just one categorical column that has missing values: `key`.

# %%
# Heatmap showing missing values in the `key` column
fig, ax = plt.subplots(figsize=(10, 5))
sns.heatmap(df.isnull(), ax=ax)
plt.show()

# %% [markdown]
# 🔧 Now we will fill the missing values in this column. But at first, let's look at the values and their frequencies in this column.

# %%
df['key'].value_counts().to_frame()
# Out:
#      count
# key
# C#     111
# G       85
# G#      81
# F       79
# D       73
# B       69
# A       66
# F#      61
# E       56
# A#      50
# D#      28

# %% [markdown]
# ❌We can apply the `mode` method to fill in missing values for the `key` column, but in reality, this approach is not really effective. Alternatively, we can identify the missing keys based on the `track_name` and `artist(s)_name` to find out the appropriate values for those missing entries. <br>
# ✅ Lukily, We can use web scrapping from `Spotify`. There is a code that we can use to get the `key` of a song from `Spotify`, i get this code from [here](https://www.kaggle.com/code/andrsgyrefi/spotify-analysis).

# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from spotipy) (1.26.18)
# Collecting async-timeout>=4.0.2 (from redis>=3.5.3->spotipy)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from requests>=2.25.0->spotipy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nien\miniconda3\envs\min_ds-env_2\lib\site-packages (from requests>=2.25.0->spotipy) (2023.7.22)
# Downloading redis-5.0.1-py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.3 kB ? eta -:--:--
#    --------- ------------------------------ 61.4/250.3 kB 1.7 MB/s eta 0:00:01
#    -------------- ------------------------- 92.2/250.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 250.3/250.3 kB 1.9 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-4.0.3 redis-5.0.1 spotipy-2.23.0

# %%
# Import the spotipy library
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Set up the Spotify API credentials
client_id = "24101b195b73495e9477d0e26779a9a3"
client_secret = "3c02a8aea8554a9899be23ddb3219c4f"

# Authenticate with Spotify
client_credentials_manager = SpotifyClientCredentials(client_id= client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_song_key(song_name):
    # Search for the song on Spotify
    results = sp.search(q = song_name, type="track", limit=1)
    tracks = results["tracks"]["items"]
    
    # Mapping of pitch class numbers to key names, rename from the offical Spotify to one which is more in-line with our database
    pitch_class_to_key = {
        0: 'C',
        1: 'C#',
        2: 'D',
        3: 'D#',
        4: 'E',
        5: 'F',
        6: 'F#',
        7: 'G',
        8: 'G#',
        9: 'A',
        10: 'A#',
        11: 'B'
    }
    
    if tracks:
        # Get the first track's ID
        track_id = tracks[0]["id"]
        
        # Retrieve the audio features for the track
        audio_features = sp.audio_features(track_id)[0]
        
        if audio_features:
        # Convert the pitch class to a key name
            key = pitch_class_to_key[audio_features['key']]
            return key
        else:
            return "Audio features not found."
    else:
        return "Song not found."

# %%
#Get the list of songs without a key based on name 
keyless = df.loc[df["key"].isnull(),"track_name"].tolist()
#Create a dictionary for the song-key pairs
song_keys = {}
for song in keyless:
    key = get_song_key(song)
    song_keys[(song)] = key

# %%
# Replace the null values based on our new data
for index, row in df.iterrows():
    if row["track_name"] in song_keys:
       df.loc[index, "key"] = song_keys[row["track_name"]]

# %% [markdown]
# 🕵️ Check the number of different values in `key` column after filling missing values.

# %%
df["key"].value_counts().to_frame()
# Out:
#      count
# key
# C#     113
# G       85
# G#      83
# F       80
# C       79
# D       74
# B       69
# A       67
# F#      62
# E       56
# A#      53
# D#      27

# %%
print(f"The number of missing values in `key` column after fill in: {df['key'].isna().sum()}")
# Out:
# The number of missing values in `key` column after fill in: 0

# %% [markdown]
# ✅ Afer filling missing values, there is new value in `key` column: `C`. It seems mostly `C` was missing from the `key` column.

# %% [markdown]
# ### 6.2  Different values in each categorical column

# %% [markdown]
# ✅ `track_name` has many different values because each song has a different name, it is understandable. So we will not check it.

# %% [markdown]
# 🕵️ We will explore the  `artist(s)_name`, `key` and `mode` columns.

# %%
df['artist(s)_name'].str.split(', ').explode().value_counts()
# Out:
# artist(s)_name
# The Weeknd        34
# Taylor Swift      34
# Bad Bunny         32
# SZA               23
# Kendrick Lamar    22
#                   ..
# Conan Gray         1
# FIFA Sound         1
# Beach House        1
# Sukriti Kakar      1
# Selena Gomez       1
# Name: count, Length: 599, dtype: int64

# %% [markdown]
# ✅There are about `599` different artists in our dataset. We can not check all of them. So, we will check the top `30` artists that have the most songs in our dataset.

# %% [markdown]
# - First 30 artist with highest numbers of songs

# %%
# Some songs have multiple artists, so we need to split the string and count the number of artists
artist_name_count = df['artist(s)_name'].str.split(', ').explode().value_counts()[:30]
fig, ax = plt.subplots(figsize=(20, 10))
ax.bar(artist_name_count.index, artist_name_count.values)
ax.set_xticks(range(len(artist_name_count.index)))
ax.set_xticklabels(artist_name_count.index, rotation=90)
ax.set_xlabel('Artist(s) name')
ax.set_ylabel('Counts')
ax.set_title('The distribution of Artist(s) name')
plt.show()

# %% [markdown]
# ✅`The Weeknd` and `Taylor Swift` are two artist that has the most songs in our dataset: `34` songs. Followed by `Bad Bunny` with `32` songs and `SZA` with `23` songs.

# %% [markdown]
# 🕵️ The distribution of `key`

# %%
key_counts = df['key'].value_counts()

fig, ax = plt.subplots(figsize=(20, 10))
ax.barh(key_counts.index, key_counts.values)
ax.set_ylabel('Keys of songs')
ax.set_xlabel('Counts')
ax.set_title('The frequency of keys of songs')
plt.show()

# %% [markdown]
# ✅ **Comment:**
# - `C#` is the most common key in our dataset with `113` songs. Followed by `G` with `85` songs and `G#` with `83` songs.
# - `C` is the new key that we have just filled missing values. But it also has a significant number of songs: `79` songs.
# - `D#` is the least common key in our dataset with `27` songs.

# %% [markdown]
# 🕵️ The distribution of `mode`

# %%
fig, ax = plt.subplots(figsize=(10, 5))
values, count = np.unique(df['mode'], return_counts=True)
ax.pie(count, autopct='%.1f%%', startangle=90, labels=values, explode=[0, 0.1])
ax.set_title('The frequency of mode')
ax.legend(values, loc='lower left')
ax.axis('equal')
plt.show()

# %% [markdown]
# ✅**Comment:**
# - `major` is the most common mode in our dataset indicating that most of the songs in our dataset give a sense of happiness, optimism, and brightness.
# - The remaining songs are in `minor` mode, which evoke a sense of sadness, melancholy, and darkness compared to the `major` mode.

# %% [markdown]
# ## 7. Correlation between attributes

# %% [markdown]
# 🕵️ First, we will check the correlation between columns related to the features of the song: `bpm`, `danceability_%`, `valence_%`, `energy_%`, `acousticness_%`, `instrumentalness_%`, `liveness_%`, `speechiness_%`.

# %% [markdown]
# -  The `Pearson correlation coefficient` does not have the ability to assess monotonic relationships between two variables (both linear and nonlinear). In this case, we need a better metric to measure this type of relationship. One such metric is the `Spearman correlation coefficient`.
# - `Pearson` and `Spearman` correlations are similar when it comes to assessing linear relationships.
# - `Spearman` is better at estimating monotonic (but nonlinear) relationships between variables, while `Pearson` tends to underestimate this type of relationship.

# %%
audio_features_columns = ['bpm','danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%','liveness_%', 'speechiness_%']
correlation_matrix = df[audio_features_columns].corr(method='spearman')
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', vmin=-1, vmax=1, cmap='coolwarm', mask=mask)
plt.title('Correlations between audio features in a song', fontsize=10, fontweight='bold')
plt.show()

# %% [markdown]
# ✅ **Comment:**
# - `valence_%` has a moderately positive correlation with `danceability_%` and `energy_%`, with correlation coefficients of `0.39` and `0.35`.
# - `acousticness_%` has a relatively large negative correlation with `energy_%`, with a correlation coefficient of `-0.5`.
# - The remaining pairs have insignificant correlations with each other.

# %% [markdown]
# 🕵️ To observe the specific correlations between `valence_%` and `danceability_%`, `energy_%`, as well as between `acousticness_%` and `energy_%`, we can use `scatter plot`.

# %%
x = ['valence_%', 'valence_%', 'acousticness_%']
y = ['danceability_%', 'energy_%', 'energy_%']
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))
for i in range(len(x)):
    sns.scatterplot(x=x[i], y=y[i], data=df, ax=axes[i], alpha=0.5)
    axes[i].set_title(f'The correlation between {x[i]} and {y[i]}', fontweight='bold')
    axes[i].set_xlabel(x[i], fontweight='bold')
    axes[i].set_ylabel(y[i], fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# 🕵️We can also use `joint plot` to combine `scatter plot` and `KDE plot` to observe the distribution of each variable and the relationship between them.

# %%
for i in range(len(x)):
    g = sns.jointplot(x=x[i], y=y[i], data=df, kind='kde', height=8, ratio=3, cmap='Blues', fill=True)
    g.set_axis_labels(x[i], y[i])

    plt.title(f'Joint Plot of {x[i]} vs {y[i]}')
    plt.show()

# %% [markdown]
# 🕵️ Finally, we will check the correlation between columns related to the number of streams, playlists and rankings of songs on different music platforms.: `in_spotify_playlists`, `in_spotify_charts`, `in_apple_playlists`, `in_apple_charts`, `in_deezer_playlists`, `in_deezer_charts`, `in_shazam_charts`.

# %%
stream_and_ranking_cols = ['streams', 'in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts']
correlation_matrix = df[stream_and_ranking_cols].corr(method='spearman')
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', vmin=-1, vmax=1, cmap='coolwarm', mask=mask)
plt.title('Correlations between streams and rankings columns', fontsize=10, fontweight='bold')
plt.show()

# %% [markdown]
# ✅**Comment:**
# - All columns have **positive correlations** with each other.
# - `streams` and columns related to the number of playlists such as `in_spotify_playlists`, `in_deezer_playlists`, and `in_apple_playlists` have **strong positive** correlations with each other.
# - Columns related to rankings such as `in_spotify_charts`, `in_apple_charts`, `in_deezer_charts`, and `in_shazam_charts` also have significant **positive correlations** with each other.

# %% [markdown]
# 🕵️ Using `scatter plot` to observe the specific correlations between `streams` and `in_spotify_playlists`, `in_deezer_playlists`, `in_apple_playlists`.

# %%
x = ['streams', 'streams', 'streams']
y = ['in_spotify_playlists', 'in_deezer_playlists', 'in_apple_playlists']
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))
for i in range(len(x)):
    sns.scatterplot(x=x[i], y=y[i], data=df, ax=axes[i], alpha=0.5)
    axes[i].set_title(f'The correlation between {x[i]} and {y[i]}', fontweight='bold')
    axes[i].set_xlabel(x[i], fontweight='bold')
    axes[i].set_ylabel(y[i], fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# <p style="text-align:center; font-size:30px;">END</p>
